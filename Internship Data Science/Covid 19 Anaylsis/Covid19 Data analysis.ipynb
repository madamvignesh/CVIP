# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\madam\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
data =  pd.read_csv(r"C:\Users\madam\Documents\Data scince\Internship Data Science\country_wise_latest.csv")

# %%
data
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.isnull().sum()
# Out:
# Country                   0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
import seaborn as sns

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\madam\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [raw]
# As we can see from heat map, the state region is light coloured which comcludes that state has null values.

# %% [markdown]
# # Show the number if deaths, recovered cases in each column.

# %%
data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.groupby('Country').sum()
# Out:
#                     Confirmed  Deaths  Recovered  Active  New cases  \
# Country
# Afghanistan             36263    1269      25198    9796        106
# Albania                  4880     144       2745    1991        117
# Algeria                 27973    1163      18837    7973        616
# Andorra                   907      52        803      52         10
# Angola                    950      41        242     667         18
# ...                       ...     ...        ...     ...        ...
# West Bank and Gaza      10621      78       3752    6791        152
# Western Sahara             10       1          8       1          0
# Yemen                    1691     483        833     375         10
# Zambia                   4552     140       2815    1597         71
# Zimbabwe                 2704      36        542    2126        192
#
#                     New deaths  New recovered  Deaths / 100 Cases  \
# Country
# ...

# %% [markdown]
# # Show only confirmed cases of all regions in the form of descending order.

# %%
data.groupby('Country').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Country
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Pakistan           274289
# Spain              272421
# Saudi Arabia       268934
# Colombia           257101
# Italy              246286
# Turkey             227019
# Bangladesh         226225
# France             220352
# Germany            207112
# Argentina          167416
# Name: Confirmed, dtype: int64

# %% [raw]
# As from above results we can see that US has the most number of recovered cases.

# %% [markdown]
# # Show both confirmed cases and recovered cases at a time.

# %%
 data.groupby('Country')['Confirmed'].sum()
# Out:
# Country
# Afghanistan           36263
# Albania                4880
# Algeria               27973
# Andorra                 907
# Angola                  950
#                       ...
# West Bank and Gaza    10621
# Western Sahara           10
# Yemen                  1691
# Zambia                 4552
# Zimbabwe               2704
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# # Remove all the records where recovered cases is less than 10.

# %%
data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data = data[~(data.Confirmed < 10)]

# %%
data.head(20)
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# ...

# %% [markdown]
# # In which region maximum number of confirmed cases are recorded?

# %%
data.groupby('Country')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Country
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Pakistan           274289
# Spain              272421
# Saudi Arabia       268934
# Colombia           257101
# Italy              246286
# Turkey             227019
# Bangladesh         226225
# France             220352
# Germany            207112
# Argentina          167416
# Name: Confirmed, dtype: int64

# %% [markdown]
# # In which region minimum number of deaths were recorded?

# %%
data.groupby('Country').Deaths.sum().sort_values(ascending = False)
# Out:
# Country
# US                148011
# Brazil             87618
# United Kingdom     45844
# Mexico             44022
# Italy              35112
#                    ...
# Laos                   0
# Greenland              0
# Cambodia               0
# Grenada                0
# Mongolia               0
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# # How many confirmed, recovered and death cases are reported from India from Aprill 29th 2020?

# %%
data[data.Country == 'India']
# Out:
#    Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 79   India    1480073   33408     951166  495499      44457         637
#
#     New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 79          33598                2.26                  64.26
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 79                    3.51              1155338         324735
#
#     1 week % increase       WHO Region
# 79              28.11  South-East Asia

# %% [markdown]
# # Sort the entire data with respect to confirmed cases in ascending order.

# %%
data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.sort_values(by = ['Confirmed'] , ascending  = True)
# Out:
#                    Country  Confirmed  Deaths  Recovered   Active  New cases  \
# 183         Western Sahara         10       1          8        1          0
# 75                Holy See         12       0         12        0          0
# 68               Greenland         14       0         13        1          1
# 140  Saint Kitts and Nevis         17       0         15        2          0
# 49                Dominica         18       0         18        0          0
# ..                     ...        ...     ...        ...      ...        ...
# 154           South Africa     452529    7067     274925   170537       7096
# 138                 Russia     816680   13334     602249   201097       5607
# 79                   India    1480073   33408     951166   495499      44457
# 23                  Brazil    2442375   87618    1846641   508116      23284
# 173                     US    4290259  148011    1325804  2816444      56336
#
# ...
